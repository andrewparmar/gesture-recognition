# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
img = cv2.imread('simple_tl.png')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# fig, ax = plt.subplots()
# ax.imshow(img)
# ax.axis('off')
# plt.show()

# %%
b_img, g_img, r_img = cv2.split(img)

plt.imshow(b_img, 'gray')
# plt.imshow(b_img)
plt.show()

plt.imshow(g_img, 'gray')
# plt.imshow(g_img)
plt.show()

plt.imshow(r_img, 'gray')
# plt.imshow(r_img)
plt.show()

# %%
# img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# plt.imshow(img_gray)
# plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
# plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2GRAY))
# cv2.waitKey(0)
# for r in range(0, 50):
g_img_blur = cv2.medianBlur(g_img,5)
circles = cv2.HoughCircles(g_img_blur, cv2.HOUGH_GRADIENT, 1, 1, param1=50, param2=1, minRadius=0,maxRadius=30)
print(circles)
print(circles.shape)
# Out:
# [[[133.5  44.5  29.4]
#   [133.5 119.5  29.4]
#   [133.5 194.5  29.4]
#   ...
#   [179.5 204.5   0.3]
#   [179.5 209.5   0.3]
#   [179.5 234.5   0.3]]]
# (1, 1896, 3)

# %%
g_img_blur = cv2.medianBlur(g_img,5)
circles = cv2.HoughCircles(g_img_blur, cv2.HOUGH_GRADIENT, 1, 30, param1=50, param2=8, minRadius=0,maxRadius=30)
print(circles)
print(circles.shape)
# Out:
# [[[133.5  44.5  29.4]
#   [133.5 119.5  29.4]
#   [133.5 194.5  29.4]]]
# (1, 3, 3)

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_gray.shape
radius = 30
circles = cv2.HoughCircles(img_gray, cv2.HOUGH_GRADIENT, 1, 2*radius, param1=50, param2=8,
#                            minRadius=0,
                           maxRadius=35)
print(circles)
print(circles.shape)
# Out:
# [[[135.5  45.5  30.8]
#   [135.5 120.5  30.8]
#   [135.5 195.5  30.8]]]
# (1, 3, 3)

# %% [markdown]
# # HSV Detections

# %%
# img = cv2.imread('simple_tl.png')
img = cv2.imread('scene_tl_1.png')
plt.imshow(img)
plt.show()
print(img.shape)
# print(img[434][188])
# print(img[434, 188])
# print(img[434][250])
# print(img[434, 250])
# print(img[434][312])
# print(img[434, 312])
img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
plt.imshow(img_hsv)
plt.show()

# img = cv2.imread('scene_tl_1.png')
# img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
# plt.imshow(img_hsv)
# plt.show()

# img = cv2.imread('scene_tl_2.png')
# img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
# plt.imshow(img_hsv)
# plt.show()
# Out:
# (600, 800, 3)

# %%
# img = cv2.imread('simple_tl.png')
img = cv2.imread('scene_tl_1.png')
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
radius = 22
circles = cv2.HoughCircles(img_gray, cv2.HOUGH_GRADIENT, 1, 2*radius, param1=50, param2=8,
                           minRadius=radius, maxRadius=radius)
print(circles)
print(circles.shape)
# Out:
# [[[434.5 187.5  23.4]
#   [434.5 249.5  23.4]
#   [434.5 311.5  23.4]]]
# (1, 3, 3)

# %%
circles = np.uint16(np.around(circles))
# print("cirlces", circles)
# print(circles[0][0])
for i in circles[0,:]:
    # draw the outer circle
    cv2.circle(img,(i[0],i[1]),i[2],(0,255,0),2)
    # draw the center of the circle
    cv2.circle(img,(i[0],i[1]),2,(0,0,255),3)
    print("i: ", i)
#     print("shape", img.shape)
    print(img[i[1], i[0]])
    print(img_hsv[i[1], i[0]])
    print()
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# for coordinate in circles[0].tolist():
#     row, col, _ = coordinate
#     print(row, col, _)
#     print(img_hsv[row, col])
# Out:
# i:  [434 188  23]
# [  0   0 255]
# [  0 255 127]
#
# i:  [434 250  23]
# [  0   0 255]
# [ 30 255 127]
#
# i:  [434 312  23]
# [  0   0 255]
# [ 60 255 255]

# %%
img = cv2.imread('simple_tl.png')
img_col = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
print(img_col.shape)
plt.imshow(img_col)
plt.show()

img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print(img_col.shape)
plt.imshow(img_gray, 'hsv')
plt.show()
# Out:
# (240, 450, 3)
# (240, 450, 3)

# %%
img = cv2.imread('scene_tl_1.png')
print(img.dtype)
fig, ax = plt.subplots()
img = cv2.GaussianBlur(img, (7,7), 0)

img_col = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
ax.imshow(img_col)
ax.axis('off')

plt.show()

img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
print(img.dtype)
b, g, r = cv2.split(img)
plt.imshow(img_gray)
plt.axis('off')
plt.show()
# Out:
# uint8
# uint8

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print(img_gray.shape)
radius = 30
circles = cv2.HoughCircles(g, cv2.HOUGH_GRADIENT, 1, 2*radius, param1=50, param2=8, maxRadius=radius)
print(circles.shape)
circles = np.uint16(np.around(circles))
print(circles)
# Out:
# (600, 800)
# (1, 4, 3)
# [[[438 188  25]
#   [438 250  25]
#   [438 312  25]
#   [664 170  29]]]

# %%
for i in circles[0,:]:
    # draw the outer circle
    cv2.circle(img,(i[0],i[1]),i[2],(0,255,0),2)
    # draw the center of the circle
    cv2.circle(img,(i[0],i[1]),2,(0,0,255),3)
# .imshow('detected circles',cimg)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
print(img.shape)

for coordinate in circles[0]:
    row, col, _ = coordinate
    print(img[row, col])
# Out:
# (600, 800, 3)
# [  0 204   0]
# [  0 204   0]
# [  0 204   0]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-163-4ea452d726fc> in <module>
#      10 for coordinate in circles[0]:
#      11     row, col, _ = coordinate
# ---> 12     print(img[row, col])
#
# IndexError: index 664 is out of bounds for axis 0 with size 600

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
