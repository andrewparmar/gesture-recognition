# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
# Color planes
img = cv2.imread('./southafricaflagface.png')
# img = cv2.imread('./porsche_carerra.png')

plt.imshow(img.astype(np.uint8))
plt.show()

b,g,r = cv2.split(img)

plt.imshow(b)
plt.show()

plt.imshow(g)
plt.show()

plt.imshow(r)
plt.show()

# %%
https://www.mathworks.com/matlabcentral/answers/326680-why-only-selecting-green-channel-of-color-image-for-binarize
    
https://hypertextbook.com/facts/2007/SusanZhao.shtml
    
https://www.quora.com/Why-do-most-digital-camera-sensors-capture-2-green-pixels-for-every-1-blue-and-1-red-pixel
    
https://medium.com/@vad710/cv-for-busy-developers-image-processing-d93ed4836880

https://www.johndcook.com/blog/2009/08/24/algorithms-convert-color-grayscale/

# %%
https://www.mathworks.com/matlabcentral/answers/39380-negative-values-of-pixels-in-aimage
